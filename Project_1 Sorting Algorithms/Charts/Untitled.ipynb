# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from pathlib import Path
import numpy as np

# %%
path = "../Results/"

# %%
fig, ax = plt.subplots(figsize=(20, 10))
x = np.linspace(1, 5, 100)
ax.plot(x, 1, 'o
ax.plot(x, x, 'o-')
ax.plot(x, np.log(x), 'o-')
ax.plot(x, x * np.log(x), 'o-')
ax.plot(x, x * x, 'o-')
ax.grid()

plt.show()

# %%
data0 = pd.read_csv(path + "heapsort.csv", sep = ";")
data1 = pd.read_csv(path + "introsort.csv", sep = ";")
data2 = pd.read_csv(path + "quicksort.csv", sep = ";")

fig, ax = plt.subplots(figsize=(20, 10))

ax.plot(data0["count"], data0["time"]/1000000, 'o-')
ax.plot(data1["count"], data1["time"]/1000000, 'o-')
ax.plot(data2["count"], data2["time"]/1000000, 'o-')

ax.grid();
ax.set(xticks = data0["count"]);

plt.xlabel("count")
plt.ylabel("time [ms]")
plt.show()

# %%
data0 = pd.read_csv(path + "heapsort reversed.csv", sep = ";")
data1 = pd.read_csv(path + "introsort reversed.csv", sep = ";")
data2 = pd.read_csv(path + "quicksort reversed.csv", sep = ";")

fig, ax = plt.subplots(figsize=(20, 10))

ax.plot(data0["count"], data0["time"]/1000000, 'o-')
ax.plot(data1["count"], data1["time"]/1000000, 'o-')
ax.plot(data2["count"], data2["time"]/1000000, 'o-')

ax.grid();
ax.set(xticks = data0["count"]);

plt.xlabel("count")
plt.ylabel("time [ms]")
plt.show()

# %%
data0 = pd.read_csv(path + "heapsort 25% already sorted.csv", sep = ";")
data1 = pd.read_csv(path + "introsort 25% already sorted.csv", sep = ";")
data2 = pd.read_csv(path + "quicksort 25% already sorted.csv", sep = ";")

fig, ax = plt.subplots(figsize=(20, 10))

ax.plot(data0["count"], data0["time"]/1000000, 'o-')
ax.plot(data1["count"], data1["time"]/1000000, 'o-')
ax.plot(data2["count"], data2["time"]/1000000, 'o-')

ax.grid();
ax.set(xticks = data0["count"]);

plt.xlabel("count")
plt.ylabel("time [ms]")
plt.show()

# %%
data0 = pd.read_csv(path + "heapsort 50% already sorted.csv", sep = ";")
data1 = pd.read_csv(path + "introsort 50% already sorted.csv", sep = ";")
data2 = pd.read_csv(path + "quicksort 50% already sorted.csv", sep = ";")

fig, ax = plt.subplots(figsize=(20, 10))

ax.plot(data0["count"], data0["time"]/1000000, 'o-')
ax.plot(data1["count"], data1["time"]/1000000, 'o-')
ax.plot(data2["count"], data2["time"]/1000000, 'o-')

ax.grid();
ax.set(xticks = data0["count"]);

plt.xlabel("count")
plt.ylabel("time")
plt.show()

# %%
data0 = pd.read_csv(path + "heapsort 75% already sorted.csv", sep = ";")
data1 = pd.read_csv(path + "introsort 75% already sorted.csv", sep = ";")
data2 = pd.read_csv(path + "quicksort 75% already sorted.csv", sep = ";")

fig, ax = plt.subplots(figsize=(20, 10))

ax.plot(data0["count"], data0["time"]/1000000, 'o-')
ax.plot(data1["count"], data1["time"]/1000000, 'o-')
ax.plot(data2["count"], data2["time"]/1000000, 'o-')

ax.grid();
ax.set(xticks = data0["count"]);

plt.xlabel("count")
plt.ylabel("time [ms]")
plt.show()

# %%
data0 = pd.read_csv(path + "heapsort 95% already sorted.csv", sep = ";")
data1 = pd.read_csv(path + "introsort 95% already sorted.csv", sep = ";")
data2 = pd.read_csv(path + "quicksort 95% already sorted.csv", sep = ";")

fig, ax = plt.subplots(figsize=(20, 10))

ax.plot(data0["count"], data0["time"]/1000000, 'o-')
ax.plot(data1["count"], data1["time"]/1000000, 'o-')
ax.plot(data2["count"], data2["time"]/1000000, 'o-')

ax.grid();
ax.set(xticks = data0["count"]);

plt.xlabel("count")
plt.ylabel("time [ms]")
plt.show()

# %%
data0 = pd.read_csv(path + "heapsort 99% already sorted.csv", sep = ";")
data1 = pd.read_csv(path + "introsort 99% already sorted.csv", sep = ";")
data2 = pd.read_csv(path + "quicksort 99% already sorted.csv", sep = ";")

fig, ax = plt.subplots(figsize=(20, 10))

ax.plot(data0["count"], data0["time"]/1000000, 'o-')
ax.plot(data1["count"], data1["time"]/1000000, 'o-')
ax.plot(data2["count"], data2["time"]/1000000, 'o-')

ax.grid();
ax.set(xticks = data0["count"]);

plt.xlabel("count")
plt.ylabel("time [ms]")
plt.show()

# %%
data0 = pd.read_csv(path + "heapsort 99.7% already sorted.csv", sep = ";")
data1 = pd.read_csv(path + "introsort 99.7% already sorted.csv", sep = ";")
data2 = pd.read_csv(path + "quicksort 99.7% already sorted.csv", sep = ";")

fig, ax = plt.subplots(figsize=(20, 10))

ax.plot(data0["count"], data0["time"]/1000000, 'o-')
ax.plot(data1["count"], data1["time"]/1000000, 'o-')
ax.plot(data2["count"], data2["time"]/1000000, 'o-')

ax.grid();
ax.set(xticks = data0["count"]);

plt.xlabel("count")
plt.ylabel("time [ms]")
plt.show()

# %%
data0 = pd.read_csv(path + "heapsort 25% already sorted.csv", sep = ";")
data1 = pd.read_csv(path + "heapsort 50% already sorted.csv", sep = ";")
data2 = pd.read_csv(path + "heapsort 75% already sorted.csv", sep = ";")
data3 = pd.read_csv(path + "heapsort 99% already sorted.csv", sep = ";")
data4 = pd.read_csv(path + "heapsort 99.7% already sorted.csv", sep = ";")


fig, ax = plt.subplots(figsize=(20, 10))

ax.plot(data0["count"], data0["time"]/1000000, 'o-')
ax.plot(data1["count"], data1["time"]/1000000, 'o-')
ax.plot(data2["count"], data2["time"]/1000000, 'o-')
ax.plot(data3["count"], data3["time"]/1000000, 'o-')
ax.plot(data4["count"], data4["time"]/1000000, 'o-')

ax.grid();
ax.set(xticks = data0["count"]);

plt.xlabel("count")
plt.ylabel("time [ms]")
plt.show()

# %%
data0 = pd.read_csv(path + "introsort 25% already sorted.csv", sep = ";")
data1 = pd.read_csv(path + "introsort 50% already sorted.csv", sep = ";")
data2 = pd.read_csv(path + "introsort 75% already sorted.csv", sep = ";")
data3 = pd.read_csv(path + "introsort 99% already sorted.csv", sep = ";")
data4 = pd.read_csv(path + "introsort 99.7% already sorted.csv", sep = ";")


fig, ax = plt.subplots(figsize=(20, 10))

ax.plot(data0["count"], data0["time"]/1000000, 'o-')
ax.plot(data1["count"], data1["time"]/1000000, 'o-')
ax.plot(data2["count"], data2["time"]/1000000, 'o-')
ax.plot(data3["count"], data3["time"]/1000000, 'o-')
ax.plot(data4["count"], data4["time"]/1000000, 'o-')

ax.grid();
ax.set(xticks = data0["count"]);

plt.xlabel("count")
plt.ylabel("time [ms]")
plt.show()

# %%
data0 = pd.read_csv(path + "quicksort 25% already sorted.csv", sep = ";")
data1 = pd.read_csv(path + "quicksort 50% already sorted.csv", sep = ";")
data2 = pd.read_csv(path + "quicksort 75% already sorted.csv", sep = ";")
data3 = pd.read_csv(path + "quicksort 99% already sorted.csv", sep = ";")
data4 = pd.read_csv(path + "quicksort 99.7% already sorted.csv", sep = ";")


fig, ax = plt.subplots(figsize=(20, 10))

ax.plot(data0["count"], data0["time"]/1000000, 'o-')
ax.plot(data1["count"], data1["time"]/1000000, 'o-')
ax.plot(data2["count"], data2["time"]/1000000, 'o-')
ax.plot(data3["count"], data3["time"]/1000000, 'o-')
ax.plot(data4["count"], data4["time"]/1000000, 'o-')

ax.grid();
ax.set(xticks = data0["count"]);

plt.xlabel("count")
plt.ylabel("time [ms]")
plt.show()
